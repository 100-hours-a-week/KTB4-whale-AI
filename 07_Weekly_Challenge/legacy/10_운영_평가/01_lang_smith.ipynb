# %%
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = "lsv2_pt_..."           # 위에서 발급한 키
os.environ["LANGSMITH_PROJECT"] = "adapterz-langchain-textbook"     # 원하는 프로젝트 이름
    
# === Google Gemini도 함께 사용 ===
os.environ["GOOGLE_API_KEY"] = "AIza..."
